# %% [markdown]
# <a href="https://colab.research.google.com/github/flaviohnm/projeto_bancodedados/blob/main/ocorrencias_nova.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Instalação do módulos

# %%
! pip install pandera
! pip install pymongo
! pip install dnspython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandera in /usr/local/lib/python3.7/dist-packages (0.9.0)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.7/dist-packages (from pandera) (1.3.5)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from pandera) (1.21.6)
# Requirement already satisfied: typing-inspect>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from pandera) (0.7.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.7/dist-packages (from pandera) (1.14.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from pandera) (4.1.1)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from pandera) (6.0.1)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.7/dist-packages (from pandera) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from pandera) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->pandera) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->pandera) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->pandera) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0->pandera) (1.15.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from typing-inspect>=0.6.0->pandera) (0.4.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/dist-packages (4.1.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: dnspython in /usr/local/lib/python3.7/dist-packages (2.2.1)

# %% [markdown]
# #Bloco de Extração

# %%
import pandas as pd
import pandera as pa
import pymongo
from pymongo import MongoClient as mc

# %%
df = pd.read_csv("/content/drive/MyDrive/projeto_bancodedados/ocorrencia.csv",sep=";",parse_dates=['ocorrencia_dia'],dayfirst=True)

# %% [markdown]
# ## O comando "head" exibe a quantidade de linhas contida no parentesis.

# %%
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              52242               52242               52242
# 1              45331               45331               45331
# 2              45333               45333               45333
# 3              45401               45401               45401
# 4              45407               45407               45407
# 5              52243               52243               52243
# 6              50713               50713               50713
# 7              45334               45334               45334
# 8              45391               45391               45391
# 9              52244               52244               52244
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               52242               52242                INCIDENTE
# 1               45331               45331                 ACIDENTE
# 2               45333               45333                 ACIDENTE
# 3               45401               45401                 ACIDENTE
# 4               45407               45407                 ACIDENTE
# 5               52243               52243                INCIDENTE
# 6               50713               50713          INCIDENTE GRAVE
# 7               45334               45334                INCIDENTE
# 8               45391               45391                 ACIDENTE
# 9               52244               52244                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude      ocorrencia_cidade  \
# 0                 NaN                  NaN           PORTO ALEGRE
# 1      -23.4355555556       -46.4730555556              GUARULHOS
# 2                 ***                  ***                 VIAMÃO
# 3                 ***                  ***          SÃO SEBASTIÃO
# 4                 ***                  ***               SÃO SEPÉ
# 5                 NaN                  NaN                UBATUBA
# 6                 ***                  ***               CAMPINAS
# 7                 NaN                  NaN                  BELÉM
# 8      -19.9133333333       -48.2930555556  CONCEIÇÃO DAS ALAGOAS
# 9                 ***                  ***             UBERLÂNDIA
#
#   ocorrencia_uf  ... ocorrencia_dia ocorrencia_hora  \
# 0            RS  ...     2012-01-05        20:27:00
# 1            SP  ...     2012-01-06        13:44:00
# 2            RS  ...     2012-01-06        13:00:00
# 3            SP  ...     2012-01-06        17:00:00
# 4            RS  ...     2012-01-06        16:30:00
# 5            SP  ...     2012-01-06        14:30:00
# 6            SP  ...     2012-01-07        18:15:00
# 7            PA  ...     2012-01-08        19:12:00
# 8            MG  ...     2012-01-08        16:00:00
# 9            MG  ...     2012-01-08        22:13:00
#
#   investigacao_aeronave_liberada investigacao_status  \
# 0                            ***          FINALIZADA
# 1                            SIM          FINALIZADA
# 2                            NaN          FINALIZADA
# 3                            ***                 NaN
# 4                            SIM          FINALIZADA
# 5                            ***          FINALIZADA
# 6                            SIM          FINALIZADA
# 7                            ***          FINALIZADA
# 8                            ***          FINALIZADA
# 9                            ***          FINALIZADA
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                         ***                            NÃO
# 1           A-582/CENIPA/2014                            SIM
# 2           A-070/CENIPA/2013                            SIM
# 3                         NaN                            NÃO
# 4           A-071/CENIPA/2013                            SIM
# 5                         ***                            NÃO
# 6          IG-184/CENIPA/2013                            SIM
# 7                         ***                            NÃO
# 8                   A DEFINIR                            NÃO
# 9                         ***                            NÃO
#
#   divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                       NaN                   0                          1
# 1                2016-09-01                   3                          1
# 2                2013-11-27                   0                          1
# 3                       NaN                   0                          1
# 4                2013-11-27                   0                          1
# 5                       NaN                   0                          1
# 6                2014-01-08                   0                          1
# 7                       NaN                   0                          1
# 8                       NaN                   0                          1
# 9                       NaN                   0                          1
#
#    ocorrencia_saida_pista
# 0                     NÃO
# 1                     NÃO
# 2                     NÃO
# 3                     NÃO
# 4                     NÃO
# 5                     NÃO
# 6                     NÃO
# 7                     NÃO
# 8                     NÃO
# 9                     NÃO
#
# [10 rows x 22 columns]

# %% [markdown]
# Exibir os tipos de dados dos objetos

# %%
df.dtypes
# Out:
# codigo_ocorrencia                          int64
# codigo_ocorrencia1                         int64
# codigo_ocorrencia2                         int64
# codigo_ocorrencia3                         int64
# codigo_ocorrencia4                         int64
# ocorrencia_classificacao                  object
# ocorrencia_latitude                       object
# ocorrencia_longitude                      object
# ocorrencia_cidade                         object
# ocorrencia_uf                             object
# ocorrencia_pais                           object
# ocorrencia_aerodromo                      object
# ocorrencia_dia                    datetime64[ns]
# ocorrencia_hora                           object
# investigacao_aeronave_liberada            object
# investigacao_status                       object
# divulgacao_relatorio_numero               object
# divulgacao_relatorio_publicado            object
# divulgacao_dia_publicacao                 object
# total_recomendacoes                        int64
# total_aeronaves_envolvidas                 int64
# ocorrencia_saida_pista                    object
# dtype: object

# %% [markdown]
# Até esse trecho foi realizado o carregamento de dados com a conversão das colunas que contém datas para o tipo de dado "date" com o método "parse".

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia                    0
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude                975
# ocorrencia_longitude               975
# ocorrencia_cidade                    0
# ocorrencia_uf                        0
# ocorrencia_pais                      0
# ocorrencia_aerodromo                 0
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada     166
# investigacao_status                257
# divulgacao_relatorio_numero        384
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         3816
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# dtype: int64

# %% [markdown]
# ##Validação do Schema

# %% [markdown]
# ##Checando se o valor da coluna "codigo ocorrência" são únicos.

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %% [markdown]
# Definindo "codigo da ocorrência" como indice

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %% [markdown]
# Consultar quantos NA tem no dataframe

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude                975
# ocorrencia_longitude               975
# ocorrencia_cidade                    0
# ocorrencia_uf                        0
# ocorrencia_pais                      0
# ocorrencia_aerodromo                 0
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada     166
# investigacao_status                257
# divulgacao_relatorio_numero        384
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         3816
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude                975
# ocorrencia_longitude               975
# ocorrencia_cidade                    0
# ocorrencia_uf                        0
# ocorrencia_pais                      0
# ocorrencia_aerodromo                 0
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada     166
# investigacao_status                257
# divulgacao_relatorio_numero        384
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         3816
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# dtype: int64

# %% [markdown]
# ###Consultas

# %%
#consulta1 | Ocorrências com Latitude e Longitude preenchida
df.query(ocorrencia_latitude != NaN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-249-90b550f25fe8> in <module>()
#       1 #consulta1 | Ocorrências com Latitude e Longitude preenchida
# ----> 2 df.query(ocorrencia_latitude != NaN)
#
# NameError: name 'ocorrencia_latitude' is not defined

# %%
ocorrencias = df

# %%
ocorrencias.head(10)
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 52242                           52242               52242               52242
# 45331                           45331               45331               45331
# 45333                           45333               45333               45333
# 45401                           45401               45401               45401
# 45407                           45407               45407               45407
# 52243                           52243               52243               52243
# 50713                           50713               50713               50713
# 45334                           45334               45334               45334
# 45391                           45391               45391               45391
# 52244                           52244               52244               52244
#
#                    codigo_ocorrencia4 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
# 52243                           52243                INCIDENTE
# 50713                           50713          INCIDENTE GRAVE
# 45334                           45334                INCIDENTE
# 45391                           45391                 ACIDENTE
# 52244                           52244                INCIDENTE
#
#                   ocorrencia_latitude ocorrencia_longitude  \
# codigo_ocorrencia
# 52242                             NaN                  NaN
# 45331                  -23.4355555556       -46.4730555556
# 45333                             ***                  ***
# 45401                             ***                  ***
# 45407                             ***                  ***
# 52243                             NaN                  NaN
# 50713                             ***                  ***
# 45334                             NaN                  NaN
# 45391                  -19.9133333333       -48.2930555556
# 52244                             ***                  ***
#
#                        ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# codigo_ocorrencia                                                       ...
# 52242                       PORTO ALEGRE            RS          BRASIL  ...
# 45331                          GUARULHOS            SP          BRASIL  ...
# 45333                             VIAMÃO            RS          BRASIL  ...
# 45401                      SÃO SEBASTIÃO            SP          BRASIL  ...
# 45407                           SÃO SEPÉ            RS          BRASIL  ...
# 52243                            UBATUBA            SP          BRASIL  ...
# 50713                           CAMPINAS            SP          BRASIL  ...
# 45334                              BELÉM            PA          BRASIL  ...
# 45391              CONCEIÇÃO DAS ALAGOAS            MG          BRASIL  ...
# 52244                         UBERLÂNDIA            MG          BRASIL  ...
#
#                   ocorrencia_dia ocorrencia_hora  \
# codigo_ocorrencia
# 52242                 2012-01-05        20:27:00
# 45331                 2012-01-06        13:44:00
# 45333                 2012-01-06        13:00:00
# 45401                 2012-01-06        17:00:00
# 45407                 2012-01-06        16:30:00
# 52243                 2012-01-06        14:30:00
# 50713                 2012-01-07        18:15:00
# 45334                 2012-01-08        19:12:00
# 45391                 2012-01-08        16:00:00
# 52244                 2012-01-08        22:13:00
#
#                   investigacao_aeronave_liberada investigacao_status  \
# codigo_ocorrencia
# 52242                                        ***          FINALIZADA
# 45331                                        SIM          FINALIZADA
# 45333                                        NaN          FINALIZADA
# 45401                                        ***                 NaN
# 45407                                        SIM          FINALIZADA
# 52243                                        ***          FINALIZADA
# 50713                                        SIM          FINALIZADA
# 45334                                        ***          FINALIZADA
# 45391                                        ***          FINALIZADA
# 52244                                        ***          FINALIZADA
#
#                   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# codigo_ocorrencia
# 52242                                     ***                            NÃO
# 45331                       A-582/CENIPA/2014                            SIM
# 45333                       A-070/CENIPA/2013                            SIM
# 45401                                     NaN                            NÃO
# 45407                       A-071/CENIPA/2013                            SIM
# 52243                                     ***                            NÃO
# 50713                      IG-184/CENIPA/2013                            SIM
# 45334                                     ***                            NÃO
# 45391                               A DEFINIR                            NÃO
# 52244                                     ***                            NÃO
#
#                   divulgacao_dia_publicacao total_recomendacoes  \
# codigo_ocorrencia
# 52242                                   NaN                   0
# 45331                            2016-09-01                   3
# 45333                            2013-11-27                   0
# 45401                                   NaN                   0
# 45407                            2013-11-27                   0
# 52243                                   NaN                   0
# 50713                            2014-01-08                   0
# 45334                                   NaN                   0
# 45391                                   NaN                   0
# 52244                                   NaN                   0
#
#                    total_aeronaves_envolvidas  ocorrencia_saida_pista
# codigo_ocorrencia
# 52242                                       1                     NÃO
# 45331                                       1                     NÃO
# 45333                                       1                     NÃO
# 45401                                       1                     NÃO
# 45407                                       1                     NÃO
# 52243                                       1                     NÃO
# 50713                                       1                     NÃO
# 45334                                       1                     NÃO
# 45391                                       1                     NÃO
# 52244                                       1                     NÃO
#
# [10 rows x 21 columns]

# %% [markdown]
# ###Dados da conexão com o MongoDB no Atlas (AWS)

# %%
uri = "mongodb+srv://mongo_user:MongoUser1234@cluster0.6qfwp.mongodb.net/starwars?retryWrites=true&w=majority" #url de conexão
client = mc(uri)

# %%
#teste de conexão com o banco
client.stats
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02.6qfwp.mongodb.net:27017', 'cluster0-shard-00-01.6qfwp.mongodb.net:27017', 'cluster0-shard-00-00.6qfwp.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-r075ws-shard-0', tls=True), 'stats')

# %%
db = client.list_database_names()
print(db)
# Out:
# ['mestrado', 'projetobd', 'starwars', 'admin', 'local']

# %%
data = ocorrencias
ocorrencias.head(10)
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 52242                           52242               52242               52242
# 45331                           45331               45331               45331
# 45333                           45333               45333               45333
# 45401                           45401               45401               45401
# 45407                           45407               45407               45407
# 52243                           52243               52243               52243
# 50713                           50713               50713               50713
# 45334                           45334               45334               45334
# 45391                           45391               45391               45391
# 52244                           52244               52244               52244
#
#                    codigo_ocorrencia4 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
# 52243                           52243                INCIDENTE
# 50713                           50713          INCIDENTE GRAVE
# 45334                           45334                INCIDENTE
# 45391                           45391                 ACIDENTE
# 52244                           52244                INCIDENTE
#
#                   ocorrencia_latitude ocorrencia_longitude  \
# codigo_ocorrencia
# 52242                             NaN                  NaN
# 45331                  -23.4355555556       -46.4730555556
# 45333                             ***                  ***
# 45401                             ***                  ***
# 45407                             ***                  ***
# 52243                             NaN                  NaN
# 50713                             ***                  ***
# 45334                             NaN                  NaN
# 45391                  -19.9133333333       -48.2930555556
# 52244                             ***                  ***
#
#                        ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# codigo_ocorrencia                                                       ...
# 52242                       PORTO ALEGRE            RS          BRASIL  ...
# 45331                          GUARULHOS            SP          BRASIL  ...
# 45333                             VIAMÃO            RS          BRASIL  ...
# 45401                      SÃO SEBASTIÃO            SP          BRASIL  ...
# 45407                           SÃO SEPÉ            RS          BRASIL  ...
# 52243                            UBATUBA            SP          BRASIL  ...
# 50713                           CAMPINAS            SP          BRASIL  ...
# 45334                              BELÉM            PA          BRASIL  ...
# 45391              CONCEIÇÃO DAS ALAGOAS            MG          BRASIL  ...
# 52244                         UBERLÂNDIA            MG          BRASIL  ...
#
#                   ocorrencia_dia ocorrencia_hora  \
# codigo_ocorrencia
# 52242                 2012-01-05        20:27:00
# 45331                 2012-01-06        13:44:00
# 45333                 2012-01-06        13:00:00
# 45401                 2012-01-06        17:00:00
# 45407                 2012-01-06        16:30:00
# 52243                 2012-01-06        14:30:00
# 50713                 2012-01-07        18:15:00
# 45334                 2012-01-08        19:12:00
# 45391                 2012-01-08        16:00:00
# 52244                 2012-01-08        22:13:00
#
#                   investigacao_aeronave_liberada investigacao_status  \
# codigo_ocorrencia
# 52242                                        ***          FINALIZADA
# 45331                                        SIM          FINALIZADA
# 45333                                        NaN          FINALIZADA
# 45401                                        ***                 NaN
# 45407                                        SIM          FINALIZADA
# 52243                                        ***          FINALIZADA
# 50713                                        SIM          FINALIZADA
# 45334                                        ***          FINALIZADA
# 45391                                        ***          FINALIZADA
# 52244                                        ***          FINALIZADA
#
#                   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# codigo_ocorrencia
# 52242                                     ***                            NÃO
# 45331                       A-582/CENIPA/2014                            SIM
# 45333                       A-070/CENIPA/2013                            SIM
# 45401                                     NaN                            NÃO
# 45407                       A-071/CENIPA/2013                            SIM
# 52243                                     ***                            NÃO
# 50713                      IG-184/CENIPA/2013                            SIM
# 45334                                     ***                            NÃO
# 45391                               A DEFINIR                            NÃO
# 52244                                     ***                            NÃO
#
#                   divulgacao_dia_publicacao total_recomendacoes  \
# codigo_ocorrencia
# 52242                                   NaN                   0
# 45331                            2016-09-01                   3
# 45333                            2013-11-27                   0
# 45401                                   NaN                   0
# 45407                            2013-11-27                   0
# 52243                                   NaN                   0
# 50713                            2014-01-08                   0
# 45334                                   NaN                   0
# 45391                                   NaN                   0
# 52244                                   NaN                   0
#
#                    total_aeronaves_envolvidas  ocorrencia_saida_pista
# codigo_ocorrencia
# 52242                                       1                     NÃO
# 45331                                       1                     NÃO
# 45333                                       1                     NÃO
# 45401                                       1                     NÃO
# 45407                                       1                     NÃO
# 52243                                       1                     NÃO
# 50713                                       1                     NÃO
# 45334                                       1                     NÃO
# 45391                                       1                     NÃO
# 52244                                       1                     NÃO
#
# [10 rows x 21 columns]

# %%
db = client['projetobd']
collection = db['ocorrencias']

# %%
#carregando o dataframe ocorrencias no mongodb
ocorrencias_dict = ocorrencias.to_dict("records")
collection.insert_many(ocorrencias_dict)

# %%
print(ocorrencias_dict)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#listando um registro já cadastrado no mongo
busca = collection.find_one()
print(busca)
# Out:
# {'_id': ObjectId('62bb5d56c9f245150b5c45dc'), 'codigo_ocorrencia1': 52242, 'codigo_ocorrencia2': 52242, 'codigo_ocorrencia3': 52242, 'codigo_ocorrencia4': 52242, 'ocorrencia_classificacao': 'INCIDENTE', 'ocorrencia_latitude': nan, 'ocorrencia_longitude': nan, 'ocorrencia_cidade': 'PORTO ALEGRE', 'ocorrencia_uf': 'RS', 'ocorrencia_pais': 'BRASIL', 'ocorrencia_aerodromo': 'SBPA', 'ocorrencia_dia': datetime.datetime(2012, 1, 5, 0, 0), 'ocorrencia_hora': '20:27:00', 'investigacao_aeronave_liberada': '***', 'investigacao_status': 'FINALIZADA', 'divulgacao_relatorio_numero': '***', 'divulgacao_relatorio_publicado': 'NÃO', 'divulgacao_dia_publicacao': nan, 'total_recomendacoes': 0, 'total_aeronaves_envolvidas': 1, 'ocorrencia_saida_pista': 'NÃO'}

# %%
#estrutura para excluir a coleção
db = client['projetobd']
collection = db['ocorrencias']
#collection.drop()
